# %%
import pandas as pd 
df = pd.read_csv("/Users/siddarthusulkar/Documents/GitHub/BMI_Applied_project/Cleaning_data.csv")
df
# Out:
#           SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0     130378.0      12.0       2.0       1.0      43.0       NaN       5.0
# 1     130379.0      12.0       2.0       1.0      66.0       NaN       3.0
# 2     130380.0      12.0       2.0       2.0      44.0       NaN       2.0
# 3     130386.0      12.0       2.0       1.0      34.0       NaN       1.0
# 4     130387.0      12.0       2.0       2.0      68.0       NaN       3.0
# ...        ...       ...       ...       ...       ...       ...       ...
# 5959  142303.0      12.0       2.0       2.0      69.0       NaN       5.0
# 5960  142305.0      12.0       2.0       2.0      76.0       NaN       1.0
# 5961  142307.0      12.0       2.0       2.0      49.0       NaN       4.0
# 5962  142309.0      12.0       2.0       1.0      40.0       NaN       2.0
# 5963  142310.0      12.0       2.0       2.0      80.0       NaN       3.0
#
# ...
