# %%
import pandas as pd
#
#pd.set_option("display.max_rows", None)
#pd.set_option("display.max_columns", None)
#pd.set_option("display.width", None)
#pd.set_option("display.max_colwidth", None)

DEMO_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/DEMO_L.xpt", format="xport")
DIQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/DIQ_L.xpt", format="xport")
GHB_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/GHB_L.xpt", format="xport")
GLU_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/GLU_L.xpt", format="xport")
HIQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/HIQ_L.xpt", format="xport")
HUQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/HUQ_L.xpt", format="xport")
INQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/INQ_L.xpt", format="xport")
UCPREG_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/UCPREG_L.xpt", format="xport")
BMX_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/BMX_L.xpt", format="xport")
PAQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/PAQ_L.xpt", format="xport")
WHQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/WHQ_L.xpt", format="xport")
SLQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/SLQ_L.xpt", format="xport")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       1 import pandas as pd
#       2 #
#       3 #pd.set_option("display.max_rows", None)
#       4 #pd.set_option("display.max_columns", None)
#       5 #pd.set_option("display.width", None)
#       6 #pd.set_option("display.max_colwidth", None)
# ----> 8 DEMO_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/DEMO_L.xpt", format="xport")
#       9 DIQ_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/DIQ_L.xpt", format="xport")
#      10 GHB_21_23 = pd.read_sas("/Users/siddarthusulkar/Documents/Project files/Data Sets/GHB_L.xpt", format="xport")
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sas/sasreader.py:156, in read_sas(filepath_or_buffer, format, index, encoding, chunksize, iterator, compression)
#     153 if format.lower() == "xport":
#     154     from pandas.io.sas.sas_xport import XportReader
# --> 156     reader = XportReader(
#     157         filepath_or_buffer,
#     158         index=index,
#     159         encoding=encoding,
#     160         chunksize=chunksize,
#     161         compression=compression,
#     162     )
#     163 elif format.lower() == "sas7bdat":
#     164     from pandas.io.sas.sas7bdat import SAS7BDATReader
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/sas/sas_xport.py:270, in XportReader.__init__(self, filepath_or_buffer, index, encoding, chunksize, compression)
#     267 self._index = index
#     268 self._chunksize = chunksize
# --> 270 self.handles = get_handle(
#     271     filepath_or_buffer,
#     272     "rb",
#     273     encoding=encoding,
#     274     is_text=False,
#     275     compression=compression,
#     276 )
#     277 self.filepath_or_buffer = self.handles.handle
#     279 try:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/siddarthusulkar/Documents/Project files/Data Sets/DEMO_L.xpt'

# %%
df = DEMO_21_23
df = df.merge(DIQ_21_23, on="SEQN", how="left")
df = df.merge(GHB_21_23, on="SEQN", how="left")
df = df.merge(GLU_21_23, on="SEQN", how="left")
df = df.merge(HIQ_21_23, on="SEQN", how="left")
df = df.merge(HUQ_21_23, on="SEQN", how="left")
df = df.merge(INQ_21_23, on="SEQN", how="left")
df = df.merge(UCPREG_21_23, on="SEQN", how="left")
df = df.merge(BMX_21_23, on="SEQN", how="left")
df = df.merge(PAQ_21_23, on="SEQN", how="left")
df = df.merge(WHQ_21_23, on="SEQN", how="left")
df = df.merge(SLQ_21_23, on="SEQN", how="left")

df.shape
# Out:
# (11933, 98)

# %%
df.to_csv("Cleaning_data_merged.csv", index=False)
print("Saved cleaned data to Cleaning_data_merged.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.to_csv("Cleaning_data_merged.csv", index=False)
#       2 print("Saved cleaned data to Cleaning_data_merged.csv")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ---------- Uptil here------
